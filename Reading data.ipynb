# %%
from collections import defaultdict, Counter
import os
from xml.dom.minidom import parse, parseString

# %%
#fairy tales
data_folder_fairy_tales = 'data/Fairy_tales/agreed/'

#ISEAR
data_folder_ISEAR = 'data/ISEAR/'

#SemEval
data_folder_sem_eval = 'data/sem_eval/'


#Map to ANGER, JOY, SADNESS, SUPRISE
mapping = {
'fairy_tales' : {'2' : 'ANGER', '3': 'NONE', '4': 'JOY', '5': 'NONE', '6': 'SADNESS', '7': 'SUPRISE'},
'ISEAR'       : {'anger': 'ANGER', 'disgust': 'NONE', 'fear' : 'NONE', 'joy': 'JOY', 'sadness': 'SADNESS', 'shame': 'NONE', 'guilt' : 'NONE'},
'sem_eval'    : {'anger' : 'ANGER', 'disgust': 'NONE', 'fear': 'NONE', 'joy': 'JOY', 'sadness': 'SADNESS', 'surprise': 'SUPRISE'},
}

# %%
'''Reading Fairy tales data'''
result_fairy_tales = []
for filename in os.listdir(data_folder_fairy_tales):
    if filename.endswith(".agree"):
        with open(data_folder_fairy_tales + '/' + filename, 'r') as f:
            for line in f.readlines():
                row = line.strip().split("@")
                result_fairy_tales.append( (mapping['fairy_tales'][row[1]], row[2]))

# %%
'''Reading ISEAR'''
result_ISEAR = []
with open(data_folder_ISEAR + '/data.csv', 'r') as f:
    for line in f.readlines():
        row = line.strip().split("---")
        result_ISEAR.append( (mapping['ISEAR'][row[1]], row[2]))

# %%
'''Reading sem_eval'''
test_gold_doc = parse('data/sem_eval/AffectiveText.test/affectivetext_test.xml')
test_sentences = 'data/sem_eval/AffectiveText.test/affectivetext_test.emotions.gold'
train_gold_doc = parse('data/sem_eval/AffectiveText.trial/affectivetext_trial.xml')
train_sentences = 'data/sem_eval/AffectiveText.trial/affectivetext_trial.emotions.gold'
emotions = ['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise', 'sentence']

result_sem_eval = defaultdict(list)
with open(test_sentences) as f:
    for line in f.readlines():
        values = line.strip().split()
        result_sem_eval[values[0]] = [emotions[values[1:].index(max(values[1:]))]]

sentences = test_gold_doc.getElementsByTagName("instance")
for sentence in sentences:
    sid = sentence.getAttribute("id")
    result_sem_eval[sid].append(sentence.firstChild.nodeValue)

with open(train_sentences) as f2:
    for line in f2.readlines():
        values = line.strip().split()
        result_sem_eval[values[0]] = [emotions[values[1:].index(max(values[1:]))]]

sentences = train_gold_doc.getElementsByTagName("instance")
for sentence in sentences:
    sid = sentence.getAttribute("id")
    result_sem_eval[sid].append(sentence.firstChild.nodeValue)


result_sem_eval = [(mapping['sem_eval'][emotion], sentence) for emotion, sentence in result_sem_eval.values()]

# %%
result_ISEAR
# Out:
# [('JOY',
#   '"[ On days when I feel close to my partner and other friends.  When I feel at peace with myself and also experience a close contact with people whom I regard greatly.]"'),
#  ('NONE',
#   '"Every time I imagine that someone I love or I could contact a serious illness, even death."'),
#  ('ANGER',
#   '"When I had been obviously unjustly treated and had no possibility of elucidating this."'),
#  ('SADNESS',
#   '"When I think about the short time that we live and relate it to the periods of my life when I think that I did not use this short time."'),
#  ('NONE',
#   '"At a gathering I found myself involuntarily sitting next to two people who expressed opinions that I considered very low and discriminating."'),
#  ('NONE',
#   '"When I realized that I was directing the feelings of discontent with myself at my partner and this way was trying to put the blame on him instead of sorting out my own feeliings."'),
#  ('NONE',
# ...

# %%
len(result_fairy_tales)
# Out:
# 1040

# %%
result_sem_eval
# Out:
# [('JOY', 'Autos drive European gains'),
#  ('NONE', 'Taliban seize rural district in southwest as police flee'),
#  ('JOY', 'New cancer drug to save a thousand lives a year'),
#  ('JOY', 'Cases: when the simple solution is the right one'),
#  ('NONE',
#   'Really?: The claim: the back seat of a car is the safest place to sit'),
#  ('SUPRISE', "'Human hair' clue in hunt for airliner"),
#  ('JOY', 'Tests of drug to block H.I.V. infection are halted over safety'),
#  ('ANGER', "Astronaut's arrest tests NASA's mettle"),
#  ('ANGER', 'G7 to China: Ease exchange rate grip'),
#  ('JOY', 'Cutting edge accessories for digital music players'),
#  ('JOY', 'iPod good for video games'),
#  ('NONE', 'Doomsday Clock ticking away'),
#  ('JOY', 'Charlie Sheen to become highest-paid sitcom star'),
#  ('JOY', 'Swingers more common than most think'),
#  ('ANGER', 'Dad locked up son, watched on TV, police say '),
#  ('JOY', 'Catholic archbishop outlines Anglican merger hopes'),
# ...

# %%
print(Counter([e for e, s in result_sem_eval]))
# Out:
# Counter({'JOY': 333, 'NONE': 321, 'SUPRISE': 237, 'SADNESS': 212, 'ANGER': 147})
